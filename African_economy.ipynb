# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
Df=pd.read_csv("African crises.csv")
Df
# Out:
#       case  cc3   country  year  systemic_crisis    exch_usd  \
# 0        1  DZA   Algeria  1870                1    0.052264
# 1        1  DZA   Algeria  1871                0    0.052798
# 2        1  DZA   Algeria  1872                0    0.052274
# 3        1  DZA   Algeria  1873                0    0.051680
# 4        1  DZA   Algeria  1874                0    0.051308
# ...    ...  ...       ...   ...              ...         ...
# 1054    70  ZWE  Zimbabwe  2009                1  354.800000
# 1055    70  ZWE  Zimbabwe  2010                0  378.200000
# 1056    70  ZWE  Zimbabwe  2011                0  361.900000
# 1057    70  ZWE  Zimbabwe  2012                0  361.900000
# 1058    70  ZWE  Zimbabwe  2013                0  361.900000
#
#       domestic_debt_in_default  sovereign_external_debt_default  \
# 0                            0                                0
# 1                            0                                0
# ...

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1059 entries, 0 to 1058
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   case                             1059 non-null   int64
#  1   cc3                              1059 non-null   object
#  2   country                          1059 non-null   object
#  3   year                             1059 non-null   int64
#  4   systemic_crisis                  1059 non-null   int64
#  5   exch_usd                         1059 non-null   float64
#  6   domestic_debt_in_default         1059 non-null   int64
#  7   sovereign_external_debt_default  1059 non-null   int64
#  8   gdp_weighted_default             1059 non-null   float64
#  9   inflation_annual_cpi             1059 non-null   float64
#  10  independence                     1059 non-null   int64
#  11  currency_crises                  1059 non-null   int64
# ...

# %%
Df.describe()
# Out:
#               case         year  systemic_crisis     exch_usd  \
# count  1059.000000  1059.000000      1059.000000  1059.000000
# mean     35.613787  1967.767705         0.077432    43.140831
# std      23.692402    33.530632         0.267401   111.475380
# min       1.000000  1860.000000         0.000000     0.000000
# 25%      15.000000  1951.000000         0.000000     0.195350
# 50%      38.000000  1973.000000         0.000000     0.868400
# 75%      56.000000  1994.000000         0.000000     8.462750
# max      70.000000  2014.000000         1.000000   744.306139
#
#        domestic_debt_in_default  sovereign_external_debt_default  \
# count               1059.000000                      1059.000000
# mean                   0.039660                         0.152975
# std                    0.195251                         0.360133
# min                    0.000000                         0.000000
# 25%                    0.000000                         0.000000
# ...

# %%
Df.isnull().sum()
# Out:
# case                               0
# cc3                                0
# country                            0
# year                               0
# systemic_crisis                    0
# exch_usd                           0
# domestic_debt_in_default           0
# sovereign_external_debt_default    0
# gdp_weighted_default               0
# inflation_annual_cpi               0
# independence                       0
# currency_crises                    0
# inflation_crises                   0
# banking_crisis                     0
# dtype: int64

# %%
#qUESTION 2; THE RELATIONSHIP BETWEEN SYSYEMIC CRISES, BANKING CRISES ANFD AFRICAN ECONOMY
Df.corr(method='spearman')
# Out:
#                                      case      year  systemic_crisis  \
# case                             1.000000  0.039273         0.010663
# year                             0.039273  1.000000         0.227475
# systemic_crisis                  0.010663  0.227475         1.000000
# exch_usd                        -0.250869  0.512162         0.174649
# domestic_debt_in_default         0.153555  0.147710         0.122158
# sovereign_external_debt_default -0.035389  0.317916         0.249850
# gdp_weighted_default            -0.000585  0.019954         0.014295
# inflation_annual_cpi             0.026830  0.309844         0.154250
# independence                     0.025191  0.507054         0.147083
# currency_crises                  0.103034  0.193589         0.120208
# inflation_crises                 0.014286  0.087773         0.172562
#
#                                  exch_usd  domestic_debt_in_default  \
# case                            -0.250869                  0.153555
# ...

# %%
import seaborn as sns

# %%
sns.catplot('systemic_crisis', data=Df, kind='count')

# %%
sns.catplot('banking_crisis', data=Df, kind='count')

# %%
import seaborn as sns

# %%
sns.catplot('currency_crises', data=Df, kind='count')

# %%
sns.distplot(Df['year'].dropna(), bins=15, kde=False)
plt.ylabel('Count')
plt.title('African Ecomony Over the years')
# Out:
# Text(0.5, 1.0, 'African Ecomony Over the years')

# %%
plt.hist(Df['year'][(Df['banking_crisis'] == 'crisis')].dropna(), bins=7, label='crisis', histtype='stepfilled')
plt.hist(Df['year'][(Df['banking_crisis'] == 'no_crisis')].dropna(), bins=7, label='no_crisis', alpha=.7, histtype='stepfilled')
plt.xlabel('year')
plt.ylabel('Count')
plt.title('Overview of banking crisis over the years')
plt.legend()

# %%
grouped_by_year = Df.groupby(['year', 'systemic_crisis', 'banking_crisis'])
grouped_by_year.size()
# Out:
# year  systemic_crisis  banking_crisis
# 1860  0                no_crisis          1
# 1861  0                no_crisis          1
# 1862  0                no_crisis          1
# 1863  0                no_crisis          1
# 1864  0                no_crisis          1
#                                          ..
# 2012  1                crisis             1
# 2013  0                no_crisis         12
#       1                crisis             1
# 2014  0                no_crisis         10
#       1                crisis             1
# Length: 215, dtype: int64

# %%
sns.catplot('year', col='systemic_crisis', data=Df, kind='count', height=7, aspect=.8)
plt.subplots_adjust(top=0.9)
plt.suptitle('African Economy', fontsize=16)
# Out:
# Text(0.5, 0.98, 'African Economy')

# %% [markdown]
# After multiple visualizations it can be concluded that africa's economy is growing rather slow over the years with little or no banking crisis and systemic crisis but
